# %%
import warnings
import scanpy as sc
import numpy as np
import pandas as pd
from joblib import Parallel, delayed
import time
import sys
from tqdm import tqdm

import matplotlib.pyplot as plt
import seaborn as sns
import hdbscan
from scipy.sparse import csr_matrix
from scipy.stats import hypergeom
from scipy.stats import pearsonr

import matplotlib.cm as cm
import matplotlib.colors as mcolors 
import time


sys.path.append('../3_DE_analysis/')
from DE_analysis_utils import *

pd.set_option('display.max_rows', 100)
sc.set_figure_params(figsize=(20, 4))
# Out:
# /Users/rzhu/miniconda3/envs/deseq/lib/python3.11/site-packages/scanpy/_utils/__init__.py:33: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('anndata')` instead.
#   from anndata import __version__ as anndata_version
# /Users/rzhu/miniconda3/envs/deseq/lib/python3.11/site-packages/scanpy/__init__.py:24: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('anndata')` instead.
#   if Version(anndata.__version__) >= Version("0.11.0rc2"):
# /Users/rzhu/miniconda3/envs/deseq/lib/python3.11/site-packages/scanpy/readwrite.py:16: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('anndata')` instead.
#   if Version(anndata.__version__) >= Version("0.11.0rc2"):

# %%
def assess_complex_enrichment(df, complexes, cluster_label, gene_name_label):
    """
    Assess pathway/complex enrichment
    """
    de_genes_per_cluster = {}
    clusters = df[cluster_label].unique()
    for cluster in clusters:
        cluster_genes = df[df[cluster_label]==cluster][gene_name_label]
        de_genes_per_cluster[cluster] = set(cluster_genes)

    N = len(df)
    
    best_result = []
    all_result = []
    for cluster, de_genes in de_genes_per_cluster.items():
        n = len(de_genes)
        best_result_for_cluster = None # Initialize a variable to track the best result for this cluster
        for complex_name, subunits in complexes.items():
            K = len(subunits)
            # Find the overlap between DE genes and complex subunits
            overlap = de_genes.intersection(subunits)
            k = len(overlap)
            
            # Calculate the p-value
            if (n > 0 and K > 0) and (k > 1): # Avoid division by zero or trivial cases
                pval = hypergeom.sf(k - 1, N, K, n) # sf is survival function
                
                # Adjust for multiple testing (e.g., using Benjamini-Hochberg)
                # This is a crucial step to avoid false positives
                # Store raw p-values and correct later
                current_result = {
                    'cluster': cluster,
                    'complex': complex_name,
                    'overlap_genes': list(overlap),
                    'overlap_fraction': len(overlap)/n,
                    'raw_p_value': pval,
                    'complex_size': K,
                    'overlap_size': len(overlap),
                    'cluster_size': n
                }
                
                if (best_result_for_cluster is None) or (pval < best_result_for_cluster['raw_p_value']):
                    best_result_for_cluster = current_result
                if len(overlap) > 1:
                    all_result.append(current_result)
        
        if best_result_for_cluster is not None:
            if best_result_for_cluster['raw_p_value']<1:
                best_result.append(best_result_for_cluster)
    
    # Convert results to a DataFrame for easy viewing
    best_result_df = pd.DataFrame(best_result)
    #best_result_df = best_result_df.sort_values(by='cluster').reset_index(drop=True)
    all_result_df = pd.DataFrame(all_result)
    #all_result_df = all_result_df.sort_values(by='cluster').reset_index(drop=True)

    return all_result_df, best_result_df

# %% [markdown]
# ### Check regulator enrichment

# %%
adata_de = sc.read_h5ad('../../../../3_expts/processed_data/CD4i_final//DE_results_all_confounders/CD4i_final.merged_DE_results_corrected.h5ad', backed='r')
adata_final = sc.read_h5ad('../../../../3_expts/processed_data/analysis_largefiles/nde50ntotal100_varfiltered_clustering_10232025.h5ad', backed='r')
de_by_guide = pd.read_csv('../3_DE_analysis/results/DE_by_guide.correlation_results.csv', index_col=0)
donor_robustness_summary = pd.read_csv('../3_DE_analysis/results/DE_donor_robustness_correlation_summary.csv', index_col=0)
de_summary_stats = pd.read_csv('../../../../3_expts/processed_data/CD4i_final/DE_results_all_confounders/DE_summary_stats_per_target_corrected.csv', index_col=0)

# %%
disease_association_df = pd.read_csv('disease_gene_associations_detailed.csv', index_col=0)
disease_association_df = disease_association_df[disease_association_df.gene_symbol.isin(de_summary_stats[(de_summary_stats.n_total_de_genes>50)&(de_summary_stats.n_cells_target>100)].target_name)]

# Parse into dictionary
disease_genes = {}
for disease_name in disease_association_df.disease_name.unique():
    disease_genes[disease_name] = set(disease_association_df[disease_association_df.disease_name==disease_name].gene_symbol)

# Run enrichment
disease_enrichment_df, _ = assess_complex_enrichment(adata_final.obs[['hdbscan', 'target_contrast_gene_name_corrected']],
                                              disease_genes, 'hdbscan', 'target_contrast_gene_name_corrected')

# %%
disease_enrichment_df.sort_values(by='raw_p_value').head(50)
# Out:
#      cluster                       complex  \
# 178       89            autoimmune disease
# 177       89                        asthma
# 242       54                     psoriasis
# 18        20          rheumatoid arthritis
# 179       89    inflammatory bowel disease
# 151        6            autoimmune disease
# 14        20            autoimmune disease
# 40        93            autoimmune disease
# 52       111            autoimmune disease
# 231       16                        asthma
# 49       111       Hashimoto's thyroiditis
# 51       111                        asthma
# 21        20            ulcerative colitis
# 239       54       Hashimoto's thyroiditis
# 209       82                        asthma
# 213       47                        asthma
# 57       111          rheumatoid arthritis
# 134       71  systemic lupus erythematosus
# 174       89               Crohn's disease
# 235      100               Crohn's disease
# 12        20        ankylosing spondylitis
# 254       79                        asthma
# 226       40            autoimmune disease
# 152        6    inflammatory bowel disease
# 214       47            autoimmune disease
# 118       14            autoimmune disease
# 0         33               Crohn's disease
# 244       67            autoimmune disease
# 247       67          rheumatoid arthritis
# 251      102          rheumatoid arthritis
# 240       54                        asthma
# 13        20                        asthma
# 169       41            autoimmune disease
# 133       71          rheumatoid arthritis
# 236      100            autoimmune disease
# 11        20               Crohn's disease
# 113       58            autoimmune disease
# 167       80            autoimmune disease
# 197       63          rheumatoid arthritis
# 181       89                     psoriasis
# 141      107            multiple sclerosis
# 47        93            ulcerative colitis
# 233       34       Hashimoto's thyroiditis
# 58       111  systemic lupus erythematosus
# 54       111    inflammatory bowel disease
# 158       98               Crohn's disease
# 130       71                celiac disease
# 44        93          rheumatoid arthritis
# 184       89            ulcerative colitis
# 172       41      type 1 diabetes mellitus
#
#                                          overlap_genes  overlap_fraction  \
# 178  [ARID1A, IL21R, FLI1, ERGIC1, STAT3, KLF2, IPM...          0.294118
# 177  [STAT3, KLF2, TBX21, IL21R, TET2, SCAF8, CDK2,...          0.147059
# 242                               [PRKRA, PTEN, FOXO1]          0.750000
# 18   [RASGRP1, TM2D1, SMAD3, CACHD1, IL12RB2, NFKB1...          0.179487
# 179  [ELF4, STAT3, BATF, IL21R, IPMK, BRD1, TET2, F...          0.161765
# 151  [TSPYL5, UBE2L3, MED13, SUPT20H, CD274, SGF29,...          0.305556
# 14   [C8orf33, RASGRP1, SLAMF7, TM2D1, SMAD3, CACHD...          0.282051
# 40   [MAU2, ARID2, B4GALNT3, RHBDF2, SP3, KLF2, BCL...          0.189655
# 52   [DMRTA2, BCL10, IKBKB, PDCD5, CD28, MAF, RNF8,...          0.163158
# 231                                    [GSTCD, INTS12]          1.000000
# 49   [PTPRC, PRKCQ, GPS2, FOXO1, TBCA, CEPT1, MAF, ...          0.047368
# 51   [PTPRC, COG6, PRKCQ, ICE2, ITK, FOXO1, PDCD5, ...          0.073684
# 21           [RASGRP1, C8orf33, SMAD3, IL12RB2, NFKB1]          0.128205
# 239                                      [PTEN, FOXO1]          0.500000
# 209                            [SCAF8, GADD45G, SMAD4]          0.375000
# 213                              [POU3F1, TRAF3, CYLD]          0.375000
# 57   [ARRDC4, RNF8, PTPRC, COG6, PRKCQ, FOXO1, CD2,...          0.068421
# 134                   [SMAD3, RASGRP1, NEMP2, IL12RB2]          0.148148
# 174            [STAT3, BATF, IL21R, IPMK, FLI1, RASA2]          0.088235
# 235                               [GMEB2, DLD, RIPOR1]          0.214286
# 12                      [SMAD3, RASGRP1, NFKB1, TM2D1]          0.102564
# 254                                   [NCOR1, TBL1XR1]          0.666667
# 226     [LAT2, HPS1, MLKL, DAP, INSR, IGF2, VWF, IL21]          0.285714
# 152       [TSPYL5, CD274, SGF29, RNFT1, MED15, UBE2L3]          0.166667
# 214                        [POU3F1, TRAF3, CCR6, CYLD]          0.500000
# 118  [TSPYL5, UBE2L3, MED13, SUPT20H, CD274, KLF10,...          0.224490
# 0    [ELP6, PTPRC, COG6, IKZF1, ATP2A2, CD28, RAVER...          0.059259
# 244                [TPD52, NDRG1, TM2D1, GATA3, ARID2]          0.384615
# 247                              [TM2D1, TPD52, GATA3]          0.230769
# 251                            [RASGRP1, ICOS, CACHD1]          0.230769
# 240                                      [PTEN, FOXO1]          0.500000
# 13                [SMAD3, ADAM19, MFHAS1, NFKB1, ICOS]          0.128205
# 169              [LAT2, HPS1, DAP, INSR, KIFAP3, IL21]          0.315789
# 133                  [SMAD3, RASGRP1, IL12RB2, CACHD1]          0.148148
# 236                   [GMEB2, TBCA, MFN2, DLD, RIPOR1]          0.357143
# 11                    [SMAD3, RASGRP1, NFKB1, IL12RB2]          0.102564
# 113  [PHF19, CISD1, NPHP4, COG6, MAN2A1, NFKBIL1, M...          0.194030
# 167                             [PLA2G4A, NDRG1, KLF4]          0.600000
# 197                                     [ARRDC4, MEN1]          0.400000
# 181                   [STAT3, IPMK, CD2, FLI1, RNF145]          0.073529
# 141                    [STARD10, MYB, PELO, CD5, CBLB]          0.058140
# 47      [PARK7, MTRR, CTH, UBE2V2, UBN1, NFKB1, NSUN6]          0.060345
# 233                                     [ZAP70, CD247]          0.181818
# 58   [PTPRC, COG6, ADAT2, GPS2, IKBKB, PDCD5, MAF, ...          0.047368
# 54   [PTPRC, TPGS2, COG6, ICE2, DNAAF5, BCL10, FOXO...          0.078947
# 158                         [GART, IL21R, IPMK, STAT3]          0.088889
# 130                                     [SMAD3, PDIA3]          0.074074
# 44   [PARK7, TPD52, TM2D1, CTH, MAU2, B4GALNT3, NFK...          0.068966
# 184                  [STAT3, IPMK, TET2, FLI1, ERGIC1]          0.073529
# 172                                        [ATM, IL21]          0.105263
#
#      raw_p_value  complex_size  overlap_size  cluster_size
# 178     0.000001           277            20            68
# 177     0.000018            88            10            68
# 242     0.000025            57             3             4
# 18      0.000062            82             7            39
# 179     0.000077           125            11            68
# 151     0.000226           277            11            36
# 14      0.000492           277            11            39
# 40      0.000587           277            22           116
# 52      0.000753           277            31           190
# 231     0.000831            88             2             2
# 49      0.000894            42             9           190
# 51      0.000920            88            14           190
# 21      0.001097            63             5            39
# 239     0.001102            42             2             4
# 209     0.001187            88             3             8
# 213     0.001187            88             3             8
# 57      0.001449            82            13           190
# 134     0.001619            59             4            27
# 174     0.001792            59             6            68
# 235     0.002182            59             3            14
# 12      0.002185            44             4            39
# 254     0.002447            88             2             3
# 226     0.002669           277             8            28
# 152     0.003050           125             6            36
# 214     0.003536           277             4             8
# 118     0.003735           277            11            49
# 0       0.004047            59             8           135
# 244     0.004254           277             5            13
# 247     0.004471            82             3            13
# 251     0.004471            82             3            13
# 240     0.004802            88             2             4
# 13      0.004837            88             5            39
# 169     0.005343           277             6            19
# 133     0.005410            82             4            27
# 236     0.006131           277             5            14
# 11      0.006380            59             4            39
# 113     0.006391           277            13            67
# 167     0.006544           277             3             5
# 197     0.006840            82             2             5
# 181     0.008274            57             5            68
# 141     0.008932            46             5            86
# 47      0.009331            63             7           116
# 233     0.009502            42             2            11
# 58      0.010000            59             9           190
# 54      0.010116           125            15           190
# 158     0.010601            59             4            45
# 130     0.010683            18             2            27
# 44      0.011983            82             8           116
# 184     0.012528            63             5            68
# 172     0.012741            28             2            19

# %% [markdown]
# ### Check downstream enrichment (didn't think of best way to get background set)

# %%
df_downstream = pd.read_csv('../../../../3_expts/processed_data/analysis_largefiles/nde50ntotal100_varfiltered_clustering_downstream_genes.csv', index_col=0)
df_downstream_top = df_downstream[(df_downstream['zscore_rank_negative_regulation']<50)|(df_downstream['zscore_rank_positive_regulation']<50)].copy()

# %%
disease_association_df = pd.read_csv('disease_gene_associations_detailed.csv', index_col=0)
disease_association_df = disease_association_df[disease_association_df.gene_symbol.isin(df_downstream_top.downstream_gene.unique())]

disease_genes = {}
for disease_name in disease_association_df.disease_name.unique():
    disease_genes[disease_name] = set(disease_association_df[disease_association_df.disease_name==disease_name].gene_symbol)

disease_enrichment_downstream_df, _ = assess_complex_enrichment(df_downstream_top, disease_genes, 'hdbscan_cluster', 'downstream_gene')

# %%
disease_enrichment_downstream_df.sort_values(by='raw_p_value').head(50)
# Out:
#      cluster                       complex  \
# 292       46            autoimmune disease
# 299       46      type 1 diabetes mellitus
# 359        2            autoimmune disease
# 405       26            autoimmune disease
# 291       46                        asthma
# 331       39            autoimmune disease
# 229       35    inflammatory bowel disease
# 173       32            autoimmune disease
# 507       85            autoimmune disease
# 528       67                     psoriasis
# 275       70            autoimmune disease
# 336       39          rheumatoid arthritis
# 494       59                        asthma
# 180       32            ulcerative colitis
# 337       39  systemic lupus erythematosus
# 327       39               Crohn's disease
# 334       39            multiple sclerosis
# 24        20    inflammatory bowel disease
# 426       29                        asthma
# 227       35            autoimmune disease
# 440       31            autoimmune disease
# 330       39                        asthma
# 413       26            ulcerative colitis
# 298       46  systemic lupus erythematosus
# 271       70               Crohn's disease
# 394       57            autoimmune disease
# 12        66            autoimmune disease
# 34        71            autoimmune disease
# 407       26    inflammatory bowel disease
# 442       31    inflammatory bowel disease
# 361        2    inflammatory bowel disease
# 138       62    inflammatory bowel disease
# 276       70    inflammatory bowel disease
# 172       32                        asthma
# 106        9            multiple sclerosis
# 295       46            multiple sclerosis
# 277       70            multiple sclerosis
# 293       46                celiac disease
# 144       62            ulcerative colitis
# 300       46            ulcerative colitis
# 485       22            autoimmune disease
# 160       17            autoimmune disease
# 95        34            autoimmune disease
# 52       101            autoimmune disease
# 526       67            autoimmune disease
# 23        20            autoimmune disease
# 131       18  systemic lupus erythematosus
# 433       29  systemic lupus erythematosus
# 5         36  systemic lupus erythematosus
# 403       26        ankylosing spondylitis
#
#                                          overlap_genes  overlap_fraction  \
# 292  [IL2RA, ATP8B2, RBPJ, ITGAM, CD109, TRAT1, ZFP...          0.255102
# 299  [SHC4, IL2RA, CTLA4, FASLG, MAPK1, CLINT1, PRK...          0.091837
# 359  [PITPNM2, PTPN1, IL18RAP, TRIB2, KCTD12, TBC1D...          0.224490
# 405  [TNFRSF14, CTSB, VEGFA, NFATC2, SOCS1, TGFBR3,...          0.224490
# 291  [CYFIP2, IL2RA, POU2AF1, KLF2, AHI1, FASLG, NI...          0.122449
# 331  [CDK6, AK4, IL7R, VEGFA, APEH, PDK1, DPP4, LEF...          0.222222
# 229  [HSPD1, PRKCQ, TNFSF8, ETS1, HNRNPAB, MBD2, RB...          0.142857
# 173  [LSP1, CDCA7, PTEN, SELL, CD28, PLEC, HSPD1, A...          0.214286
# 507  [IL2RA, IL7R, ALOX5AP, MCL1, HSPD1, KIF21B, LT...          0.214286
# 528  [UBLCP1, ACTR2, IL4R, FOXO1, DDX39B, SP140L, C...          0.091837
# 275  [CLEC2D, CXCR4, STAT3, P2RY10, DUSP5, CDKN1B, ...          0.212121
# 336  [DPP4, LEF1, NARF, ITGA4, NRP1, SPRED2, TCF7, ...          0.111111
# 494  [PELI2, BCL2, OTULINL, SCAF8, MAP4K4, TCF7, CD...          0.112245
# 180  [LSP1, FKBP5, GPSM1, SELL, CD28, DOCK5, IL12RB...          0.091837
# 337  [LEF1, CSK, NRP1, IL7R, SPRED2, TCF7, BACH2, V...          0.090909
# 327  [ITGA4, IL7R, SPRED2, BACH2, IL18R1, NFKB1, PD...          0.090909
# 334   [LEF1, AK4, IL7R, SPRED2, ZC3HAV1L, TCF7, BACH2]          0.070707
# 24   [FADS2, CD274, THADA, TNIP1, COX4I1, DR1, C12o...          0.122449
# 426  [CYFIP2, IL2RA, ARHGAP15, IRF4, IKBKE, CDC42SE...          0.102041
# 227  [TNFSF8, SLC44A2, PCMTD1, SAMHD1, HSPD1, PRKCQ...          0.193878
# 440  [APOBR, TRAT1, PREX1, PSMB9, TLR1, LAT2, HELZ2...          0.193878
# 330  [DPP4, UBAC2, IL7R, SPRED2, STAT6, TCF7, BACH2...          0.101010
# 413  [TNFRSF14, KIF21B, UBE2V2, CD40LG, VEGFA, CYCS...          0.081633
# 298  [IL2RA, CTLA4, KLF2, AHI1, FASLG, CD47, BMP2K,...          0.081633
# 271  [HINT1, STAT3, RBM17, DUSP5, IFNG, MCL1, FEN1,...          0.080808
# 394  [TMEM258, GFI1, SIT1, ITPK1, IKBKB, STK24, SHC...          0.183673
# 12   [NR3C2, SP110, HCFC1, ETS1, CTSH, RBM17, NUP20...          0.183673
# 34   [HINT1, STAT3, FADS2, CD3E, HNRNPAB, PPM1G, CL...          0.183673
# 407  [CYCS, TNFRSF14, KIF21B, UBE2V2, NFATC2, CD40L...          0.112245
# 442  [TLR1, APOBR, HELZ2, ETS1, PGAP1, PPM1G, TRABD...          0.112245
# 361  [DUSP16, ITGA4, IL18RAP, PPIF, KCTD12, TBC1D1,...          0.112245
# 138  [TMEM258, ICE2, STK24, NFKB1, GALC, TGFB1, CLU...          0.112245
# 276  [HINT1, STAT3, RBM17, CLK1, HSPE1, DUSP5, IFNG...          0.111111
# 172  [CD63, ZC3H12D, CKAP4, PTEN, IER5L, CD28, JAK2...          0.091837
# 106        [BATF3, RRAS2, GNG2, CLEC2D, CXCR4, TRIM14]          0.061224
# 295        [IL2RA, AHI1, MAPK1, CD109, ZFP36L1, RGS14]          0.061224
# 277         [STAT3, RBM17, CXCR4, CLEC2D, JAK1, SATB1]          0.060606
# 293                     [FASLG, IL2RA, POU2AF1, CTLA4]          0.040816
# 144  [TMEM258, NREP, STK24, GALC, NFKB1, DNMT3A, TR...          0.071429
# 300  [IL2RA, CD200, PDCD1, HDAC7, SEPTIN9, ZFP36L1,...          0.071429
# 485  [SAT1, STAT3, FADS2, CD3E, AGO2, PTPN1, KIF21B...          0.173469
# 160  [CDK6, IRF2BP2, PREX1, GPR65, ETS1, CORO1A, KI...          0.173469
# 95   [NDC80, SMC4, SAE1, TXK, TESPA1, RRM1, SGO1, C...          0.173469
# 52   [PSMG1, FYB1, MAL, PTPRC, HSPD1, TP53INP1, HSP...          0.173469
# 526  [UBLCP1, IGSF9B, ARHGAP15, KCTD20, ACTR2, C2or...          0.173469
# 23   [PHGDH, HDGF, CDK6, FADS2, CD274, THADA, TNIP1...          0.173469
# 131  [DUSP22, PPARGC1B, ETS1, IKZF1, GPD2, MYC, STAT4]          0.071429
# 433  [IL2RA, ARHGAP15, HSPD1, HSPE1, ACAP1, MYC, IK...          0.071429
# 5    [RASGRP1, ARHGAP15, HSPD1, HSPE1, DRAP1, ACAP1...          0.071429
# 403               [TNFRSF14, KIF21B, CD2, CTH, ANXA11]          0.051020
#
#       raw_p_value  complex_size  overlap_size  cluster_size
# 292  1.306959e-07           436            25            98
# 299  3.031204e-06            68             9            98
# 359  7.475485e-06           436            22            98
# 405  7.475485e-06           436            22            98
# 291  8.737764e-06           143            12            98
# 331  8.903875e-06           436            22            99
# 229  1.034793e-05           197            14            98
# 173  2.570037e-05           436            21            98
# 507  2.570037e-05           436            21            98
# 528  2.604050e-05            88             9            98
# 275  3.022250e-05           436            21            99
# 336  3.802923e-05           138            11            99
# 494  4.810993e-05           143            11            98
# 180  6.174200e-05            98             9            98
# 337  7.249031e-05            99             9            99
# 327  7.846203e-05           100             9            99
# 334  1.822685e-04            66             7            99
# 24   2.072289e-04           197            12            98
# 426  2.391611e-04           143            10            98
# 227  2.537555e-04           436            19            98
# 440  2.537555e-04           436            19            98
# 330  2.600884e-04           143            10            99
# 413  3.655703e-04            98             8            98
# 298  3.918265e-04            99             8            98
# 271  4.495903e-04           100             8            99
# 394  7.263000e-04           436            18            98
# 12   7.263000e-04           436            18            98
# 34   7.263000e-04           436            18            98
# 407  8.091554e-04           197            11            98
# 442  8.091554e-04           197            11            98
# 361  8.091554e-04           197            11            98
# 138  8.091554e-04           197            11            98
# 276  8.817532e-04           197            11            99
# 172  1.066099e-03           143             9            98
# 106  1.163764e-03            66             6            98
# 295  1.163764e-03            66             6            98
# 277  1.227086e-03            66             6            99
# 293  1.502011e-03            28             4            98
# 144  1.893334e-03            98             7            98
# 300  1.893334e-03            98             7            98
# 485  1.948575e-03           436            17            98
# 160  1.948575e-03           436            17            98
# 95   1.948575e-03           436            17            98
# 52   1.948575e-03           436            17            98
# 526  1.948575e-03           436            17            98
# 23   1.948575e-03           436            17            98
# 131  2.007579e-03            99             7            98
# 433  2.007579e-03            99             7            98
# 5    2.007579e-03            99             7            98
# 403  2.573963e-03            53             5            98
