# %%
import warnings
import scanpy as sc
import numpy as np
import pandas as pd
from joblib import Parallel, delayed
import time
import sys
from tqdm import tqdm

import matplotlib.pyplot as plt
import seaborn as sns
import hdbscan
from scipy.sparse import csr_matrix
from scipy.stats import hypergeom
from scipy.stats import pearsonr

import matplotlib.cm as cm
import matplotlib.colors as mcolors 
import time


sys.path.append('../3_DE_analysis/')
from DE_analysis_utils import *

pd.set_option('display.max_rows', 100)
sc.set_figure_params(figsize=(20, 4))
# Out:
# /Users/rzhu/miniconda3/envs/deseq/lib/python3.11/site-packages/scanpy/_utils/__init__.py:33: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('anndata')` instead.
#   from anndata import __version__ as anndata_version
# /Users/rzhu/miniconda3/envs/deseq/lib/python3.11/site-packages/scanpy/__init__.py:24: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('anndata')` instead.
#   if Version(anndata.__version__) >= Version("0.11.0rc2"):
# /Users/rzhu/miniconda3/envs/deseq/lib/python3.11/site-packages/scanpy/readwrite.py:16: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('anndata')` instead.
#   if Version(anndata.__version__) >= Version("0.11.0rc2"):

# %%
def assess_complex_enrichment(df, complexes, cluster_label, gene_name_label):
    """
    Assess pathway/complex enrichment
    """
    de_genes_per_cluster = {}
    clusters = df[cluster_label].unique()
    for cluster in clusters:
        cluster_genes = df[df[cluster_label]==cluster][gene_name_label]
        de_genes_per_cluster[cluster] = set(cluster_genes)

    N = len(df[gene_name_label].unique())
    
    best_result = []
    all_result = []
    for cluster, de_genes in de_genes_per_cluster.items():
        n = len(de_genes)
        best_result_for_cluster = None # Initialize a variable to track the best result for this cluster
        for complex_name, subunits in complexes.items():
            K = len(subunits)
            # Find the overlap between DE genes and complex subunits
            overlap = de_genes.intersection(subunits)
            k = len(overlap)
            
            # Calculate the p-value
            if (n > 0 and K > 0) and (k > 1): # Avoid division by zero or trivial cases
                pval = hypergeom.sf(k - 1, N, K, n) # sf is survival function
                
                # Adjust for multiple testing (e.g., using Benjamini-Hochberg)
                # This is a crucial step to avoid false positives
                # Store raw p-values and correct later
                current_result = {
                    'cluster': cluster,
                    'complex': complex_name,
                    'overlap_genes': list(overlap),
                    'overlap_fraction': len(overlap)/n,
                    'raw_p_value': pval,
                    'complex_size': K,
                    'overlap_size': len(overlap),
                    'cluster_size': n
                }
                
                if (best_result_for_cluster is None) or (pval < best_result_for_cluster['raw_p_value']):
                    best_result_for_cluster = current_result
                if len(overlap) > 1:
                    all_result.append(current_result)
        
        if best_result_for_cluster is not None:
            if best_result_for_cluster['raw_p_value']<1:
                best_result.append(best_result_for_cluster)
    
    # Convert results to a DataFrame for easy viewing
    best_result_df = pd.DataFrame(best_result)
    #best_result_df = best_result_df.sort_values(by='cluster').reset_index(drop=True)
    all_result_df = pd.DataFrame(all_result)
    #all_result_df = all_result_df.sort_values(by='cluster').reset_index(drop=True)

    return all_result_df, best_result_df

# %% [markdown]
# ### Check regulator enrichment

# %%
#adata_de = sc.read_h5ad('../../../../3_expts/processed_data/CD4i_final//DE_results_all_confounders/CD4i_final.merged_DE_results_corrected.h5ad', backed='r')
adata_final = sc.read_h5ad('../../../../3_expts/processed_data/analysis_largefiles/nde50ntotal50_varfiltered_simple_clustering.h5ad', backed='r')
de_by_guide = pd.read_csv('../3_DE_analysis/results/DE_by_guide.correlation_results.csv', index_col=0)
donor_robustness_summary = pd.read_csv('../3_DE_analysis/results/DE_donor_robustness_correlation_summary.csv', index_col=0)
de_summary_stats = pd.read_csv('../../../../3_expts/processed_data/CD4i_final/DE_results_all_confounders/DE_summary_stats_per_target_corrected.csv', index_col=0)

# %%
adata_final = sc.read_h5ad('../../../../3_expts/processed_data/analysis_largefiles/nde50ntotal100_varfiltered_simple_clustering.h5ad', backed='r')

# %%
disease_association_df = pd.read_csv('disease_gene_associations_detailed.csv', index_col=0)
disease_association_df = disease_association_df[disease_association_df.gene_symbol.isin(de_summary_stats[(de_summary_stats.n_total_de_genes>50)&(de_summary_stats.n_cells_target>50)].target_name_corrected)]

# Parse into dictionary
disease_genes = {}
for disease_name in disease_association_df.disease_name.unique():
    disease_genes[disease_name] = set(disease_association_df[disease_association_df.disease_name==disease_name].gene_symbol)

# Run enrichment
disease_enrichment_df, _ = assess_complex_enrichment(adata_final.obs[['hdbscan', 'target_contrast_gene_name_corrected']],
                                              disease_genes, 'hdbscan', 'target_contrast_gene_name_corrected')

# %%
disease_enrichment_df.loc[60, 'overlap_genes']
# Out:
# ['IRF4',
#  'CD247',
#  'CD28',
#  'PTPRC',
#  'PDCD5',
#  'HTT',
#  'SIK3',
#  'PRKCQ',
#  'TBX21',
#  'ITK',
#  'TESPA1',
#  'RAD51B',
#  'FOXO1',
#  'ICE2',
#  'STAT5A',
#  'COG6']

# %%
disease_enrichment_df.loc[56, 'overlap_genes']
# Out:
# ['IRF4',
#  'CD247',
#  'CD28',
#  'PTPRC',
#  'STAT5B',
#  'PDCD5',
#  'STAT6',
#  'IL4R',
#  'HTT',
#  'SIK3',
#  'PRKCQ',
#  'TBX21',
#  'ITK',
#  'RAD51B',
#  'FOXO1',
#  'ICE2',
#  'STAT5A',
#  'COG6']

# %%
disease_enrichment_df[disease_enrichment_df.cluster==99]
# Out:
#      cluster                       complex  \
# 167       90               Crohn's disease
# 168       90       Hashimoto's thyroiditis
# 169       90        ankylosing spondylitis
# 170       90                        asthma
# 171       90            autoimmune disease
# 172       90                celiac disease
# 173       90    inflammatory bowel disease
# 174       90            multiple sclerosis
# 175       90                     psoriasis
# 176       90          rheumatoid arthritis
# 177       90  systemic lupus erythematosus
# 178       90      type 1 diabetes mellitus
# 179       90            ulcerative colitis
#
#                                          overlap_genes  overlap_fraction  \
# 167          [CD28, PTPRC, RAVER1, ZAP70, FOXO1, COG6]           0.03750
# 168  [IRF4, CD247, PTPRC, TBX21, PRKCQ, TBCA, CREBB...           0.06250
# 169               [CD28, USP24, CD2, FOXO1, RNF8, MAF]           0.03750
# 170  [IRF4, CD247, CD28, PTPRC, PDCD5, HTT, SIK3, P...           0.08125
# 171  [IRF4, CD247, IKBKB, TPGS2, BCL10, RNF8, MEN1,...           0.19375
# 172                         [IRF4, PRKCQ, CD28, RTRAF]           0.02500
# 173  [IRF4, CD28, PTPRC, MAX, TPGS2, RAVER1, PRKCQ,...           0.09375
# 174                   [CD28, PTPRC, BCL10, MALT1, MAF]           0.03125
# 175                   [IRF4, FIGNL1, CD28, CD2, FOXO1]           0.03125
# 176  [IRF4, CD28, PTPRC, USP24, CD2, RAVER1, PRKCQ,...           0.08125
# 177    [PTPRC, IKBKB, PDCD5, RAD51B, ADAT2, MAF, COG6]           0.04375
# 178                                        [IRF4, MAF]           0.01250
# 179    [MAX, CD28, ZAP70, DNAAF5, FOXO1, BCL10, XRCC2]           0.04375
#
#      raw_p_value  complex_size  overlap_size  cluster_size
# 167     0.334476            49             6           160
# 168     0.000700            33            10           160
# 169     0.102750            34             6           160
# 170     0.069623            87            13           160
# 171     0.035379           235            31           160
# 172     0.073794            17             4           160
# 173     0.069167           104            15           160
# 174     0.303250            38             5           160
# 175     0.463119            46             5           160
# 176     0.010898            68            13           160
# 177     0.231603            52             7           160
# 178     0.733384            26             2           160
# 179     0.231603            52             7           160

# %%
disease_enrichment_df.sort_values(by='raw_p_value').head(50)
# Out:
#      cluster                       complex  \
# 196       54            autoimmune disease
# 195       54                        asthma
# 20        55          rheumatoid arthritis
# 199       54                     psoriasis
# 197       54    inflammatory bowel disease
# 277       23                        asthma
# 176       82            ulcerative colitis
# 132       43          rheumatoid arthritis
# 285       80          rheumatoid arthritis
# 283       80        ankylosing spondylitis
# 286       65       Hashimoto's thyroiditis
# 14        55        ankylosing spondylitis
# 276      101    inflammatory bowel disease
# 160       15            autoimmune disease
# 133       43  systemic lupus erythematosus
# 124       43               Crohn's disease
# 192       54               Crohn's disease
# 289       65                     psoriasis
# 203       54            ulcerative colitis
# 219       68                     psoriasis
# 53        -1               Crohn's disease
# 249       67          rheumatoid arthritis
# 167       82               Crohn's disease
# 280       20       Hashimoto's thyroiditis
# 172       82    inflammatory bowel disease
# 270       34            autoimmune disease
# 232      124       Hashimoto's thyroiditis
# 292      131    inflammatory bowel disease
# 161       15    inflammatory bowel disease
# 117       14            autoimmune disease
# 2         19                        asthma
# 129       43                celiac disease
# 64        -1      type 1 diabetes mellitus
# 194       54        ankylosing spondylitis
# 54        -1       Hashimoto's thyroiditis
# 23        55            ulcerative colitis
# 259       29       Hashimoto's thyroiditis
# 287       65                        asthma
# 190       33      type 1 diabetes mellitus
# 16        55            autoimmune disease
# 229       25                        asthma
# 185       30          rheumatoid arthritis
# 272       34                     psoriasis
# 198       54            multiple sclerosis
# 75       127          rheumatoid arthritis
# 69       127                        asthma
# 159       15        ankylosing spondylitis
# 101       91  systemic lupus erythematosus
# 187       33            autoimmune disease
# 267       88      type 1 diabetes mellitus
#
#                                          overlap_genes  overlap_fraction  \
# 196  [FLI1, CD2, HDAC7, IMMP1L, BRD1, IPMK, STAT5B,...          0.304878
# 195  [TBX21, FLI1, STAT3, PPA2, SCAF8, KLF2, BCL3, ...          0.146341
# 20   [TM2D1, PLA2G4A, SMAD3, CACHD1, ICOS, IL12RB2,...          0.184211
# 199  [LRRC25, FLI1, STAT3, RNF145, IPMK, CD2, HDAC7...          0.097561
# 197  [STAT3, FLI1, BRD1, ACTB, ELF4, IPMK, HDAC7, E...          0.158537
# 277                                    [GSTCD, INTS12]          1.000000
# 176                  [STAT3, IPMK, WAPL, IRF1, CD2BP2]          0.142857
# 132           [CD244, SMAD3, CACHD1, IL12RB2, RASGRP1]          0.178571
# 285                        [METRN, NPEPPS, MAU2, BRD1]          0.222222
# 283                              [METRN, NPEPPS, BRD1]          0.166667
# 286                                      [FOXO1, PTEN]          0.333333
# 14                    [TM2D1, PLA2G4A, SMAD3, RASGRP1]          0.105263
# 276                                 [BRPF1, BATF, DR1]          0.428571
# 160  [UBE2L3, TSPYL5, SCYL3, MED15, MED13, PSMB9, C...          0.305556
# 133                   [IL12RB2, NEMP2, RASGRP1, SMAD3]          0.142857
# 124                   [IL12RB2, CD244, RASGRP1, SMAD3]          0.142857
# 192      [FLI1, STAT3, ACTB, IPMK, HDAC7, BATF, RASA2]          0.085366
# 289                                      [FOXO1, PTEN]          0.333333
# 203     [STAT3, FLI1, ACTB, IPMK, HDAC7, ERGIC1, TET2]          0.085366
# 219                                      [ACTR2, FLI1]          0.285714
# 53   [FLI1, FOSL2, RIPOR1, ARPC2, HDAC7, IL7R, WBP4...          0.045028
# 249                            [RASGRP1, ICOS, CACHD1]          0.214286
# 167                         [IRF1, IPMK, IL21R, STAT3]          0.114286
# 280                                     [ZAP70, CD247]          0.181818
# 172           [IL21R, STAT3, IPMK, WAPL, IRF1, CD2BP2]          0.171429
# 270     [IL21, DAP, LAT2, VWF, IGF2, INSR, HPS1, MLKL]          0.307692
# 232                              [TBX21, ZAP70, CD247]          0.100000
# 292                                       [IRF4, BATF]          0.500000
# 161       [UBE2L3, TSPYL5, MED15, CD274, RNFT1, SGF29]          0.166667
# 117  [UBE2L3, TAF11, TSPYL5, SGF29, SCYL3, MED13, P...          0.255319
# 2    [NFATC2, COG6, ACO2, CD28, TASOR, CARD11, UBE2...          0.085526
# 129                                     [SMAD3, PDIA3]          0.071429
# 64   [GADD45G, FLI1, EMB, TYK2, TRIB2, NAA25, PTEN,...          0.024390
# 194                    [STAT3, FLI1, BRD1, CD2, HDAC7]          0.060976
# 54   [IL21R, TBCA, TAF11, CBLB, CREBBP, TYK2, TRIB2...          0.031895
# 23                  [IL12RB2, RASGRP1, SMAD3, C8orf33]          0.105263
# 259                                      [FOXO1, PTEN]          0.153846
# 287                                      [FOXO1, PTEN]          0.333333
# 190                                        [IL21, ATM]          0.105263
# 16   [TM2D1, PLA2G4A, SMAD3, C8orf33, CACHD1, ICOS,...          0.263158
# 229                              [IL2RB, ID2, SMARCE1]          0.200000
# 185                                     [MEN1, ARRDC4]          0.285714
# 272                                 [DAP, IL21, RAD50]          0.115385
# 198                 [STAT3, IMMP1L, ATP23, PPA2, BATF]          0.060976
# 75   [COG6, PRKCQ, CD28, MEN1, MAF, PTPRC, RAD51B, ...          0.077519
# 69   [SIK3, COG6, PRKCQ, CD28, ICE2, PTPRC, PDCD5, ...          0.085271
# 159                             [MED13, UBE2L3, PSMB9]          0.083333
# 101                               [C1S, ADAT2, FAM98B]          0.115385
# 187              [IL21, DAP, LAT2, KIFAP3, INSR, HPS1]          0.315789
# 267                                      [PHIP, PRKD2]          0.090909
#
#      raw_p_value  complex_size  overlap_size  cluster_size
# 196     0.000061           301            25            82
# 195     0.000331           102            12            82
# 20      0.000704            89             7            38
# 199     0.001241            58             8            82
# 197     0.001511           137            13            82
# 277     0.002205           102             2             2
# 176     0.003633            66             5            35
# 132     0.004901            89             5            28
# 285     0.005273            89             4            18
# 283     0.005528            45             3            18
# 286     0.005766            44             2             6
# 14      0.007215            45             4            38
# 276     0.007215           137             3             7
# 160     0.007440           301            11            36
# 133     0.007931            63             4            28
# 124     0.008384            64             4            28
# 192     0.009414            64             7            82
# 289     0.009901            58             2             6
# 203     0.011102            66             7            82
# 219     0.013624            58             2             7
# 53      0.013992            64            24           533
# 249     0.017657            89             3            14
# 167     0.018368            64             4            35
# 280     0.019817            44             2            11
# 172     0.020475           137             6            35
# 270     0.020656           301             8            26
# 232     0.021773            44             3            30
# 292     0.021980           137             2             4
# 161     0.023325           137             6            36
# 117     0.023382           301            12            47
# 2       0.023699           102            13           152
# 129     0.024146            19             2            28
# 64      0.024982            31            13           533
# 194     0.025773            45             5            82
# 54      0.026655            44            17           533
# 23      0.026816            66             4            38
# 259     0.027390            44             2            13
# 287     0.029197           102             2             6
# 190     0.029243            31             2            19
# 16      0.030416           301            10            38
# 229     0.030670           102             3            15
# 185     0.030750            89             2             7
# 272     0.030755            58             3            26
# 198     0.035764            49             5            82
# 75      0.036131            89            10           129
# 69      0.037261           102            11           129
# 159     0.037282            45             3            36
# 101     0.038044            63             3            26
# 187     0.038423           301             6            19
# 267     0.038467            31             2            22

# %%
disease_enrichment_df.sort_values(by='raw_p_value').head(50)
# Out:
#      cluster                       complex  \
# 176       85            autoimmune disease
# 175       85                        asthma
# 19        56          rheumatoid arthritis
# 177       85    inflammatory bowel disease
# 267       50                        asthma
# 86        -1                        asthma
# 54       114       Hashimoto's thyroiditis
# 154       91               Crohn's disease
# 91        -1                     psoriasis
# 56       114                        asthma
# 273       54          rheumatoid arthritis
# 271       54        ankylosing spondylitis
# 15        56            autoimmune disease
# 129       51  systemic lupus erythematosus
# 83        -1               Crohn's disease
# 22        56            ulcerative colitis
# 147       18            autoimmune disease
# 278       39          rheumatoid arthritis
# 162       91          rheumatoid arthritis
# 13        56        ankylosing spondylitis
# 157       91                        asthma
# 179       85                     psoriasis
# 47       104          rheumatoid arthritis
# 245       97          rheumatoid arthritis
# 43       104            autoimmune disease
# 158       91            autoimmune disease
# 161       91                     psoriasis
# 141      112            multiple sclerosis
# 172       85               Crohn's disease
# 269       24       Hashimoto's thyroiditis
# 178       85            multiple sclerosis
# 148       18    inflammatory bowel disease
# 128       51          rheumatoid arthritis
# 125       51                celiac disease
# 222       75                     psoriasis
# 276       48                        asthma
# 163       91            ulcerative colitis
# 219       75               Crohn's disease
# 256       22       Hashimoto's thyroiditis
# 170       41      type 1 diabetes mellitus
# 165       33          rheumatoid arthritis
# 113       21            autoimmune disease
# 226       80                        asthma
# 167       41            autoimmune disease
# 159       91    inflammatory bowel disease
# 85        -1        ankylosing spondylitis
# 146       18        ankylosing spondylitis
# 120       51               Crohn's disease
# 0         35               Crohn's disease
# 263       42            autoimmune disease
#
#                                          overlap_genes  overlap_fraction  \
# 176  [IRF4, FAM20B, BATF, STAT3, ARID1A, RASA2, ELF...          0.301370
# 175  [IRF4, CDK2, KLF2, IL21R, PPA2, FLI1, STAT3, T...          0.150685
# 19   [IL12RB2, TM2D1, PLA2G4A, SMAD3, RASGRP1, ICOS...          0.175000
# 177  [IRF4, IL21R, BRD1, FLI1, ELF4, BATF, IPMK, ST...          0.164384
# 267                                    [GSTCD, INTS12]          1.000000
# 86   [CDK2, HDAC3, SIK3, ARHGAP27, PTEN, PTPRC, CYL...          0.073059
# 54   [IRF4, CD247, PTPRC, CEPT1, GPS2, TBX21, PRKCQ...          0.053398
# 154                         [IPMK, IL21R, STAT3, IRF1]          0.190476
# 91   [FIGNL1, PTPN2, AHR, PTEN, DAP, PRKRA, FOXO1, ...          0.050228
# 56   [IRF4, CD247, CD28, PTPRC, STAT5B, PDCD5, STAT...          0.087379
# 273                        [MAU2, METRN, NPEPPS, BRD1]          0.235294
# 271                              [METRN, NPEPPS, BRD1]          0.176471
# 15   [CIP2A, C8orf33, IL12RB2, TM2D1, PLA2G4A, SLAM...          0.300000
# 129                   [NEMP2, IL12RB2, SMAD3, RASGRP1]          0.148148
# 83   [PTPN2, AHR, ACTB, RASA2, PTPRC, CYLD, DAP, GA...          0.050228
# 22           [C8orf33, IL12RB2, SMAD3, RASGRP1, NDRG1]          0.125000
# 147  [UBE2L3, TSPYL5, MED13, PSMB9, SGF29, SCYL3, M...          0.305556
# 278                                     [POU3F1, CCR6]          0.500000
# 162                        [NPAS2, IL21R, STAT3, IRF1]          0.190476
# 13                    [SMAD3, RASGRP1, TM2D1, PLA2G4A]          0.100000
# 157                        [NPAS2, IL21R, STAT3, IRF1]          0.190476
# 179             [IRF4, CD2, FLI1, IPMK, STAT3, RNF145]          0.082192
# 47   [TPD52, CTH, TM2D1, B4GALNT3, BPNT2, TYK2, LBH...          0.089286
# 245                            [ICOS, RASGRP1, CACHD1]          0.214286
# 43   [LBH, ACTMAP, NSUN6, SP3, TM2D1, B4GALNT3, UBE...          0.214286
# 158     [IL21R, IPMK, ATP23, STAT3, NPAS2, IRF1, DEF8]          0.333333
# 161                                [IPMK, STAT3, IRF1]          0.142857
# 141                    [MYB, PELO, CD5, CBLB, STARD10]          0.070423
# 172            [IL21R, FLI1, IPMK, BATF, STAT3, RASA2]          0.082192
# 269                                     [CD247, ZAP70]          0.181818
# 178                 [PPA2, BATF, ATP23, STAT3, IMMP1L]          0.068493
# 148       [UBE2L3, TSPYL5, SGF29, MED15, CD274, RNFT1]          0.166667
# 128                  [IL12RB2, SMAD3, RASGRP1, CACHD1]          0.148148
# 125                                     [SMAD3, PDIA3]          0.074074
# 222                                      [FLI1, ACTR2]          0.222222
# 276                                   [TBL1XR1, NCOR1]          0.333333
# 163                                [IPMK, STAT3, IRF1]          0.142857
# 219                                      [ARPC2, FLI1]          0.222222
# 256                                      [PTEN, FOXO1]          0.153846
# 170                                        [IL21, ATM]          0.105263
# 165                                     [ARRDC4, MEN1]          0.285714
# 113  [UBE2L3, KLF10, TSPYL5, MED13, PSMB9, CD274, S...          0.244898
# 226                                   [GADD45G, SCAF8]          0.285714
# 167              [IL21, KIFAP3, DAP, INSR, HPS1, LAT2]          0.315789
# 159                         [IPMK, IL21R, STAT3, IRF1]          0.190476
# 85   [HDAC7, IMMP2L, DAP, PTPN2, BRD1, AHR, FLI1, P...          0.034247
# 146                             [UBE2L3, MED13, PSMB9]          0.083333
# 120                          [IL12RB2, SMAD3, RASGRP1]          0.111111
# 0    [CD28, ARPC2, PTPRC, RAVER1, IKZF1, ATP2A2, EL...          0.059701
# 263          [IL21, INSR, HPS1, VWF, MLKL, IGF2, LAT2]          0.280000
#
#      raw_p_value  complex_size  overlap_size  cluster_size
# 176     0.000260           282            22            73
# 175     0.000336            91            11            73
# 19      0.001191            85             7            40
# 177     0.001981           129            12            73
# 267     0.002065            91             2             2
# 86      0.002226            91            32           438
# 54      0.003217            43            11           206
# 154     0.003225            61             4            21
# 91      0.003787            58            22           438
# 56      0.004240            91            18           206
# 273     0.004802            85             4            17
# 271     0.005510            44             3            17
# 15      0.007038           282            12            40
# 129     0.007322            59             4            27
# 83      0.007636            61            22           438
# 22      0.008069            64             5            40
# 147     0.008401           282            11            36
# 278     0.010210            85             2             4
# 162     0.010598            85             4            21
# 13      0.010609            44             4            40
# 157     0.013420            91             4            21
# 179     0.017578            58             6            73
# 47      0.018503            85            10           112
# 245     0.019408            85             3            14
# 43      0.020263           282            24           112
# 158     0.020862           282             7            21
# 161     0.021468            58             3            21
# 141     0.021949            46             5            71
# 172     0.022115            61             6            73
# 269     0.022129            43             2            11
# 178     0.024467            46             5            73
# 148     0.025585           129             6            36
# 128     0.025586            85             4            27
# 125     0.026256            19             2            27
# 222     0.026304            58             2             9
# 276     0.027461            91             2             6
# 163     0.027833            64             3            21
# 219     0.028916            61             2             9
# 256     0.030538            43             2            13
# 170     0.031992            30             2            19
# 165     0.032864            85             2             7
# 113     0.035700           282            12            49
# 226     0.037315            91             2             7
# 167     0.041251           282             6            19
# 159     0.042483           129             4            21
# 85      0.042576            44            15           438
# 146     0.043240            44             3            36
# 120     0.047411            61             3            27
# 0       0.048360            61             8           134
# 263     0.052410           282             7            25

# %%
disease_enrichment_df.sort_values(by='raw_p_value').head(50)
# Out:
#      cluster                       complex  \
# 243       79    inflammatory bowel disease
# 245       79                     psoriasis
# 240       79               Crohn's disease
# 19        35          rheumatoid arthritis
# 58        99       Hashimoto's thyroiditis
# 199       19                        asthma
# 218       80            autoimmune disease
# 242       79            autoimmune disease
# 48        -1            autoimmune disease
# 22        35            ulcerative colitis
# 139        9            autoimmune disease
# 222       80  systemic lupus erythematosus
# 13        35        ankylosing spondylitis
# 244       79            multiple sclerosis
# 205       78      type 1 diabetes mellitus
# 50        -1    inflammatory bowel disease
# 15        35            autoimmune disease
# 247       79            ulcerative colitis
# 147       90       Hashimoto's thyroiditis
# 54        -1  systemic lupus erythematosus
# 225       25          rheumatoid arthritis
# 140        9    inflammatory bowel disease
# 149       90            autoimmune disease
# 236       44            autoimmune disease
# 46        -1        ankylosing spondylitis
# 248       22       Hashimoto's thyroiditis
# 156       38          rheumatoid arthritis
# 246       79          rheumatoid arthritis
# 66        99          rheumatoid arthritis
# 117       10            autoimmune disease
# 60        99                        asthma
# 252       85          rheumatoid arthritis
# 152       90                     psoriasis
# 241       79                        asthma
# 148       90                        asthma
# 45        -1       Hashimoto's thyroiditis
# 138        9        ankylosing spondylitis
# 146       90               Crohn's disease
# 230       51            autoimmune disease
# 53        -1          rheumatoid arthritis
# 237       44    inflammatory bowel disease
# 6         21            multiple sclerosis
# 224       25            multiple sclerosis
# 105       30               Crohn's disease
# 238       44                     psoriasis
# 154       90            ulcerative colitis
# 44        -1               Crohn's disease
# 250       85                        asthma
# 235       44               Crohn's disease
# 143        9          rheumatoid arthritis
#
#                                          overlap_genes  overlap_fraction  \
# 243                          [IPMK, STAT3, IRF4, BATF]          0.666667
# 245                                [IPMK, STAT3, IRF4]          0.500000
# 240                                [IPMK, STAT3, BATF]          0.500000
# 19   [PLA2G4A, RASGRP1, CACHD1, IL12RB2, ICOS, SMAD...          0.189189
# 58   [GPS2, MAF, CD247, FOXO1, PRKCQ, CREBBP, IRF4,...          0.056410
# 199                            [HDAC3, NCOR1, TBL1XR1]          0.500000
# 218  [KLF2, BHLHE40, IMMP1L, RASA2, CNOT4, FAM20B, ...          0.317073
# 242                          [IPMK, STAT3, IRF4, BATF]          0.666667
# 48   [ZNF644, PPA2, MYB, HSPE1, FAM98B, REL, SYK, G...          0.185185
# 22           [C8orf33, RASGRP1, IL12RB2, SMAD3, NDRG1]          0.135135
# 139  [PSMB9, SUPT20H, TADA2B, MED15, UBE2L3, MED13,...          0.323529
# 222                [CNOT4, FAM20B, LRRC25, KLF2, FLI1]          0.121951
# 13                    [PLA2G4A, SMAD3, RASGRP1, TM2D1]          0.108108
# 244                                      [STAT3, BATF]          0.333333
# 205                                  [IL21, IGF2, ATM]          0.096774
# 50   [ZNF644, HSPE1, REL, SYK, GATA3, MAX, MBD2, UB...          0.091358
# 15   [C8orf33, PLA2G4A, SLAMF7, RASGRP1, CACHD1, CI...          0.297297
# 247                                      [IPMK, STAT3]          0.333333
# 147                               [PTEN, NPAS2, IL21R]          0.120000
# 54   [HSPE1, FAM98B, DMAC1, REL, FLI1, TRIB2, ZNF23...          0.049383
# 225                              [TPD52, GATA3, TM2D1]          0.214286
# 140       [MED15, UBE2L3, CD274, SGF29, TSPYL5, RNFT1]          0.176471
# 149  [PTEN, STAT3, ATP23, WAPL, NPAS2, IPMK, DEF8, ...          0.320000
# 236                      [IL21, DAP, INSR, HPS1, LAT2]          0.416667
# 46   [PSMB9, PTPN2, USP24, HDAC7, NFKB1, FOXO1, AHR...          0.037037
# 248                                     [ZAP70, CD247]          0.181818
# 156                                     [MEN1, ARRDC4]          0.333333
# 246                                      [STAT3, IRF4]          0.333333
# 66   [RAVER1, MAF, FOXO1, TESPA1, PRKCQ, MEN1, IRF4...          0.071795
# 117  [PSMB9, SUPT20H, TADA2B, UBE2L3, MED13, KLF10,...          0.261905
# 60   [CD247, FOXO1, PDCD5, SIK3, TESPA1, PRKCQ, ICE...          0.082051
# 252                                       [IL4R, RBPJ]          0.285714
# 152                                [PTEN, STAT3, IPMK]          0.120000
# 241                                      [STAT3, IRF4]          0.333333
# 148                        [PTEN, STAT3, NPAS2, IL21R]          0.160000
# 45   [PTEN, PTPN2, TRIB2, CBLB, FOXO1, IL7R, GATA3,...          0.034568
# 138                             [PSMB9, UBE2L3, MED13]          0.088235
# 146                               [IPMK, STAT3, IL21R]          0.120000
# 230      [ADAT2, TET2, FOXO1, CREBBP, PELO, ALG1, MPI]          0.304348
# 53   [REL, GATA3, RNF8, MAPK14, FLI1, USP24, FOXO1,...          0.059259
# 237                                  [IL21, DAP, HPS1]          0.250000
# 6    [BCL10, RREB1, PTPRC, CARD11, MALT1, IKZF1, CD28]          0.051852
# 224                                     [GATA3, TM2D1]          0.142857
# 105          [PTPN2, NFKB1, MMP9, CISD1, COG6, ATP2A2]          0.068966
# 238                                        [IL21, DAP]          0.166667
# 154                                [IPMK, STAT3, WAPL]          0.120000
# 44   [PTPN2, HDAC7, NFKB1, AHR, FOXO1, PLEKHH2, IL7...          0.044444
# 250                                      [IL4R, STAT6]          0.285714
# 235                                        [IL21, DAP]          0.166667
# 143                    [UBE2L3, SUPT20H, MED13, PSMB9]          0.117647
#
#      raw_p_value  complex_size  overlap_size  cluster_size
# 243     0.000224           120             4             6
# 245     0.000412            53             3             6
# 240     0.000485            56             3             6
# 19      0.000648            78             7            37
# 58      0.001900            40            11           195
# 199     0.002238            94             3             6
# 218     0.003462           268            13            41
# 242     0.004984           268             4             6
# 48      0.005700           268            75           405
# 22      0.005817            60             5            37
# 139     0.005940           268            11            34
# 222     0.007851            58             5            41
# 13      0.007933            41             4            37
# 244     0.008073            45             2             6
# 205     0.009357            27             3            31
# 50      0.010715           120            37           405
# 15      0.011897           268            11            37
# 247     0.014122            60             2             6
# 147     0.015272            40             3            25
# 54      0.016403            58            20           405
# 225     0.018492            78             3            14
# 140     0.019240           120             6            34
# 149     0.019620           268             8            25
# 236     0.019952           268             5            12
# 46      0.020596            41            15           405
# 248     0.021944            40             2            11
# 156     0.023339            78             2             6
# 246     0.023339            78             2             6
# 66      0.028368            78            14           195
# 117     0.030686           268            11            42
# 60      0.031322            94            16           195
# 252     0.031795            78             2             7
# 152     0.032278            53             3            25
# 241     0.033185            94             2             6
# 148     0.034199            94             4            25
# 45      0.036667            40            14           405
# 138     0.037062            41             3            34
# 146     0.037196            56             3            25
# 230     0.037280           268             7            23
# 53      0.037516            78            24           405
# 237     0.037523           120             3            12
# 6       0.040199            45             7           135
# 224     0.043311            45             2            14
# 105     0.043603            56             6            87
# 238     0.043806            53             2            12
# 154     0.044328            60             3            25
# 44      0.044805            56            18           405
# 250     0.044950            94             2             7
# 235     0.048433            56             2            12
# 143     0.051083            78             4            34

# %%
disease_enrichment_df.sort_values(by='raw_p_value').head(50)
# Out:
#      cluster                       complex  \
# 203       92    inflammatory bowel disease
# 39        -1               Crohn's disease
# 45        -1    inflammatory bowel disease
# 187       93            autoimmune disease
# 155       18                        asthma
# 205       92                     psoriasis
# 168       90       Hashimoto's thyroiditis
# 200       92               Crohn's disease
# 17        16          rheumatoid arthritis
# 41        -1        ankylosing spondylitis
# 190       93  systemic lupus erythematosus
# 202       92            autoimmune disease
# 192       67            multiple sclerosis
# 213       72                        asthma
# 48        -1          rheumatoid arthritis
# 107       40            autoimmune disease
# 132       98                celiac disease
# 47        -1                     psoriasis
# 43        -1            autoimmune disease
# 162       27      type 1 diabetes mellitus
# 176       90          rheumatoid arthritis
# 51        -1            ulcerative colitis
# 42        -1                        asthma
# 193       67          rheumatoid arthritis
# 186       93                        asthma
# 210       42       Hashimoto's thyroiditis
# 12        16            autoimmune disease
# 215      100    inflammatory bowel disease
# 10        16        ankylosing spondylitis
# 114       50          rheumatoid arthritis
# 196       37       Hashimoto's thyroiditis
# 40        -1       Hashimoto's thyroiditis
# 49        -1  systemic lupus erythematosus
# 85        33            autoimmune disease
# 153       68            autoimmune disease
# 171       90            autoimmune disease
# 108       40    inflammatory bowel disease
# 13        16                celiac disease
# 201       92                        asthma
# 161       27                     psoriasis
# 199       37                     psoriasis
# 204       92            multiple sclerosis
# 130       98               Crohn's disease
# 151       68       Hashimoto's thyroiditis
# 99        73            autoimmune disease
# 84        33        ankylosing spondylitis
# 185       93        ankylosing spondylitis
# 9         16               Crohn's disease
# 38        28            ulcerative colitis
# 18        16  systemic lupus erythematosus
#
#                                          overlap_genes  overlap_fraction  \
# 203              [IRF4, IPMK, BATF, STAT3, RASA2, DR1]          0.400000
# 39   [PTPN2, BATF, STAT3, ACTB, ATP2A2, NAA25, DAP,...          0.061765
# 45   [KEAP1, PTPN2, BATF, STAT3, ACTB, NDRG1, ATP2A...          0.105882
# 187  [STAT5B, KLF2, BHLHE40, CNOT4, BRD1, FAM20B, F...          0.473684
# 155                            [HDAC3, TBL1XR1, NCOR1]          0.750000
# 205                        [IRF4, IPMK, STAT3, LRRC25]          0.266667
# 168  [IRF4, CD247, PTPRC, TBX21, PRKCQ, TBCA, CREBB...          0.062500
# 200                         [IPMK, BATF, RASA2, STAT3]          0.266667
# 17      [IL12RB2, TM2D1, SMAD3, RASGRP1, ICOS, CACHD1]          0.200000
# 41   [HDAC7, IMMP2L, MAPK14, UBE2L3, DAP, PTPN2, BR...          0.044118
# 190                        [FLI1, KLF2, CNOT4, FAM20B]          0.210526
# 202      [IRF4, LRRC25, IPMK, BATF, STAT3, RASA2, DR1]          0.466667
# 192                             [GATA3, IMMP1L, TM2D1]          0.230769
# 213                                    [GSTCD, INTS12]          1.000000
# 48   [KEAP1, PTPN2, RBPJ, STAT3, ARRDC4, MEN1, DAP,...          0.070588
# 107  [TSPYL5, MED13, PSMB9, SGF29, SCYL3, MED15, TA...          0.333333
# 132                                      [ADO, GNPDA2]          0.166667
# 47   [FIGNL1, UBE2L3, HDAC7, FUBP1, DAP, PTPN2, LRR...          0.050000
# 43   [TNPO1, KEAP1, SMAD7, PTPN2, BATF, STAT3, RBPJ...          0.185294
# 162                                  [IL21, ATM, IGF2]          0.107143
# 176  [IRF4, CD28, PTPRC, USP24, CD2, RAVER1, PRKCQ,...          0.081250
# 51   [HDAC7, ATXN10, MAPK14, UBE2L3, DAP, PTPN2, IL...          0.052941
# 42   [DNAJC21, HDAC3, STAT3, PTEN, TRAF3, GATA3, FO...          0.079412
# 193                              [GATA3, TM2D1, TPD52]          0.230769
# 186                        [STAT5B, TBX21, KLF2, FLI1]          0.210526
# 210                                     [CD247, ZAP70]          0.181818
# 12   [CIP2A, IL12RB2, TM2D1, SLAMF7, PDIA3, SMAD3, ...          0.300000
# 215                                       [IRF4, BATF]          0.500000
# 10                             [SMAD3, RASGRP1, TM2D1]          0.100000
# 114                                     [ARRDC4, MEN1]          0.333333
# 196                                      [PTEN, FOXO1]          0.166667
# 40   [TNPO1, IL21R, PTPN2, CEPT1, ARID2, CBLB, CREB...          0.035294
# 49   [UBE2L3, KLF2, KEAP1, TRAF3, PTPN2, PPHLN1, IL...          0.050000
# 85   [UBE2L3, TSPYL5, MED13, PSMB9, CD274, SGF29, S...          0.261905
# 153             [MPI, PELO, CREBBP, TRIB2, TET2, ALG1]          0.333333
# 171  [IRF4, CD247, IKBKB, TPGS2, BCL10, RNF8, MEN1,...          0.193750
# 108               [TSPYL5, SGF29, MED15, CD274, RNFT1]          0.166667
# 13                                      [SMAD3, PDIA3]          0.066667
# 201                                [IRF4, BCL3, STAT3]          0.200000
# 161                                 [IL21, RAD50, DAP]          0.107143
# 199                                      [PTEN, FOXO1]          0.166667
# 204                                      [BATF, STAT3]          0.133333
# 130                                     [ADO, RPS6KB1]          0.166667
# 151                                    [CREBBP, TRIB2]          0.111111
# 99   [ARPC2, MYB, VHL, AHR, CYCS, CEP43, CCR6, ACTR...          0.228070
# 84                              [UBE2L3, MED13, PSMB9]          0.071429
# 185                                       [FLI1, BRD1]          0.105263
# 9                            [IL12RB2, SMAD3, RASGRP1]          0.100000
# 38                   [NSUN6, CTH, UBE2V2, SMAD3, MTRR]          0.072464
# 18                           [IL12RB2, SMAD3, RASGRP1]          0.100000
#
#      raw_p_value  complex_size  overlap_size  cluster_size
# 203     0.000168           104             6            15
# 39      0.000270            49            21           340
# 45      0.000394           104            36           340
# 187     0.000510           235             9            19
# 155     0.000541            87             3             4
# 205     0.000571            46             4            15
# 168     0.000700            33            10           160
# 200     0.000729            49             4            15
# 17      0.001049            68             6            30
# 41      0.001454            34            15           340
# 190     0.002370            52             4            19
# 202     0.002486           235             7            15
# 192     0.002727            38             3            13
# 213     0.002733            87             2             2
# 48      0.002833            68            24           340
# 107     0.006083           235            10            30
# 132     0.006173            17             2            12
# 47      0.006846            46            17           340
# 43      0.007662           235            63           340
# 162     0.008694            26             3            28
# 176     0.010898            68            13           160
# 51      0.011735            52            18           340
# 42      0.011746            87            27           340
# 193     0.014117            68             3            13
# 186     0.015053            87             4            19
# 210     0.018956            33             2            11
# 12      0.019032           235             9            30
# 215     0.021592           104             2             4
# 10      0.022028            34             3            30
# 114     0.022423            68             2             6
# 196     0.022466            33             2            12
# 40      0.025068            33            12           340
# 49      0.025481            52            17           340
# 85      0.027627           235            11            42
# 153     0.032190           235             6            18
# 171     0.035379           235            31           160
# 108     0.035992           104             5            30
# 13      0.036498            17             2            30
# 201     0.040344            87             3            15
# 161     0.040502            46             3            28
# 199     0.041790            46             2            12
# 204     0.044666            38             2            15
# 130     0.046913            49             2            12
# 151     0.048347            33             2            18
# 99      0.050558           235            13            57
# 84      0.052704            34             3            42
# 185     0.056324            34             2            19
# 9       0.056533            49             3            30
# 38      0.061899            52             5            69
# 18      0.065400            52             3            30

# %% [markdown]
# ### Check downstream enrichment (didn't think of best way to get background set)

# %%
df_downstream = pd.read_csv('../../../../3_expts/processed_data/analysis_largefiles/nde75ntotal50_varfiltered_simple_clustering_downstream_genes.csv', index_col=0)
df_downstream_top = df_downstream[(df_downstream['zscore_rank_negative_regulation']<50)|(df_downstream['zscore_rank_positive_regulation']<50)].copy()

# %%
disease_association_df = pd.read_csv('disease_gene_associations_detailed.csv', index_col=0)
disease_association_df = disease_association_df[disease_association_df.gene_symbol.isin(df_downstream_top.downstream_gene.unique())]
#disease_association_df = disease_association_df[disease_association_df.gene_symbol.isin(adata_de.obs.target_contrast_gene_name_corrected.unique())]

disease_genes = {}
for disease_name in disease_association_df.disease_name.unique():
    disease_genes[disease_name] = set(disease_association_df[disease_association_df.disease_name==disease_name].gene_symbol)

disease_enrichment_downstream_df, _ = assess_complex_enrichment(df_downstream_top, disease_genes, 'hdbscan_cluster', 'downstream_gene')

# %%
disease_enrichment_downstream_df.sort_values(by='raw_p_value').head(50)
# Out:
#       cluster                       complex  \
# 845        79          rheumatoid arthritis
# 841        79                celiac disease
# 840        79            autoimmune disease
# 517        82      type 1 diabetes mellitus
# 846        79  systemic lupus erythematosus
# 674        55            autoimmune disease
# 313        38            ulcerative colitis
# 1114       94                        asthma
# 338        73    inflammatory bowel disease
# 676        55            multiple sclerosis
# 777        69                     psoriasis
# 933       108                        asthma
# 543       111    inflammatory bowel disease
# 418        27    inflammatory bowel disease
# 930       108               Crohn's disease
# 1120       94          rheumatoid arthritis
# 1113       94        ankylosing spondylitis
# 511        82                celiac disease
# 957        89            autoimmune disease
# 760        59            autoimmune disease
# 673        55                        asthma
# 837        79       Hashimoto's thyroiditis
# 507        82       Hashimoto's thyroiditis
# 852        81                        asthma
# 839        79                        asthma
# 499        64    inflammatory bowel disease
# 1096       46    inflammatory bowel disease
# 549       111            ulcerative colitis
# 942       108            ulcerative colitis
# 678        55          rheumatoid arthritis
# 330        96  systemic lupus erythematosus
# 150        97  systemic lupus erythematosus
# 1091       46               Crohn's disease
# 408        87          rheumatoid arthritis
# 515        82          rheumatoid arthritis
# 82         16          rheumatoid arthritis
# 498        64            autoimmune disease
# 510        82            autoimmune disease
# 122        88            autoimmune disease
# 151        97      type 1 diabetes mellitus
# 513        82            multiple sclerosis
# 843        79            multiple sclerosis
# 308        38            multiple sclerosis
# 80         16            multiple sclerosis
# 509        82                        asthma
# 628        50                        asthma
# 247        76                        asthma
# 179        54                        asthma
# 1004       85                        asthma
# 685        86                        asthma
#
#                                           overlap_genes  overlap_fraction  \
# 845   [JADE2, GPR174, CD28, STAT4, IRF8, PDE4A, P2RY...          0.173469
# 841   [CD28, STAT4, CTLA4, UBE2E3, AEBP2, SH2B3, CIITA]          0.071429
# 840   [CD28, IKBKE, PDE4A, SESN1, SH2B3, CIITA, CAMK...          0.295918
# 517   [CD44, IL2RA, SHC4, STAT4, FASLG, CD6, GLUL, G...          0.102041
# 846   [JADE2, RYBP, STAT4, IKBKE, IRF8, DRAP1, CTLA4...          0.122449
# 674   [TMEM116, PSMB9, RBM17, PHGDH, TNFSF8, DPP4, I...          0.288660
# 313   [SEPTIN9, LSP1, CD28, FYB1, DOCK5, SELL, SATB1...          0.112245
# 1114  [CXCR4, RAD50, MAP4K4, IL2RA, ASS1, IL13, ICOS...          0.142857
# 338   [GPR183, RYBP, RAP2C, MTRR, STK24, NT5E, ALOX5...          0.163265
# 676   [IL7R, CARD11, TIMMDC1, RBM17, SATB1, CD69, TN...          0.092784
# 777   [RAD50, C18orf54, PREP, ATG5, RNF145, ERN1, UB...          0.102041
# 933   [CXCR4, HDAC7, ADAM19, ZC3H12D, FOXP1, RAD50, ...          0.132653
# 543   [TNFRSF14, TAGAP, PSMG1, RYBP, TUFM, CD226, CO...          0.153061
# 418   [TNFSF8, PRKCQ, ATP2A2, IL10RA, RBM17, STK38, ...          0.153061
# 930   [HDAC7, FOXP1, AHR, IL18R1, CREM, CD226, IL18R...          0.102041
# 1120  [IFNGR2, STAT1, IL2RA, IL13, NARF, ICOS, UQCC2...          0.122449
# 1113  [IFNGR2, IL2RA, NARF, IFNG, SH2B3, CEMIP2, STAT3]          0.071429
# 511                   [IL2RA, CCR1, STAT4, FASLG, CCR2]          0.051020
# 957   [PSMB9, PGAP1, TLR1, IFI30, DGKA, AGPAT4, SYNE...          0.255102
# 760   [CD28, NELL2, IFI30, GPR174, DPP4, ZNF644, SPA...          0.255102
# 673   [TRAF1, RAPH1, IL7R, CARD11, NRROS, DPP4, CCR4...          0.123711
# 837   [GPR174, STAT4, CTLA4, TRIB2, TCF7, SESN1, SH2B3]          0.071429
# 507     [CD44, IL21R, IL2RA, STAT4, GATA3, NBL1, NEMP2]          0.071429
# 852   [KLF3, CARD11, ZC3H12D, ID2, RIN3, GATA3, ANXA...          0.122449
# 839   [ZC3H12D, RYBP, CD28, IKBKE, RNF125, STAT5A, T...          0.122449
# 499   [C12orf75, MCL1, PMAIP1, CORO1A, CD226, CD6, S...          0.142857
# 1096  [C8orf33, TNFSF8, FOXO1, ATP2A2, GALC, ARPC2, ...          0.141414
# 549   [TNFRSF14, TAGAP, PSMG1, RYBP, TUFM, NFKBIA, I...          0.091837
# 942   [HDAC7, AHR, RYBP, IL18R1, CREM, IL18RAP, NFKB...          0.091837
# 678   [TRAF1, CORO1A, DPP4, CD2, P2RY10, PSMB9, RIN3...          0.113402
# 330   [CD44, JARID2, PTPN22, LBH, CSK, HSPD1, HSPE1,...          0.091837
# 150   [IL10, CD44, PTPN22, ADAT2, FASLG, HSPD1, ARL4...          0.091837
# 1091  [TNFSF8, FOXO1, ATP2A2, GALC, ARPC2, FOSL2, RN...          0.090909
# 408   [CASP8, MIF, RASGRP1, CD2, FAS, PTPRC, PRDM1, ...          0.112245
# 515   [IL21R, IL2RA, IGSF9B, STAT4, FUT8, CD6, IFNG,...          0.112245
# 82    [TAGAP, MIF, IL21R, RHOH, CORO1A, PTGER4, PRDM...          0.112245
# 498   [CD5, CYCS, SESN1, FADS2, AEN, PMAIP1, CD6, CT...          0.244898
# 510   [CD5, ERN1, GATA3, ZDHHC14, CD44, IL21R, STAT4...          0.244898
# 122   [AGO2, FEN1, RNF19A, PIM3, FOXP1, CD44, JARID2...          0.244898
# 151    [IL10, CD44, PTPN22, CDK1, FASLG, CD69, TNFAIP3]          0.071429
# 513       [IL2RA, STAT4, CD5, CD6, TGFBR3, CD58, GATA3]          0.071429
# 843      [CD28, STAT4, IRF8, TGFBR3, TCF7, TYMP, SH2B3]          0.071429
# 308        [AHI1, CD28, ITGA1, SATB1, LEF1, GNG2, NCF4]          0.071429
# 80    [FOXP1, TAGAP, SMAD7, PTGER4, ZFP36L1, ZFP36L2...          0.071429
# 509   [ADAM19, IL21R, IL2RA, MAP4K4, ID2, FASLG, IL2...          0.112245
# 628   [CXCR4, CYFIP2, DPP4, SLC39A8, BCL2, MYC, IFIH...          0.112245
# 247   [ADAM19, FEN1, SOCS1, RYBP, LBH, ANXA2, ZBTB10...          0.112245
# 179   [TRAF3, GNPDA1, CD28, IRF4, FOXO1, IKZF1, JAK2...          0.112245
# 1004  [IRF4, DPP4, PTPRC, IL5, ARHGAP15, RBM15B, SES...          0.112245
# 685   [ADAM19, TRAF1, IL21R, POU2AF1, RNF125, STAU2,...          0.112245
#
#       raw_p_value  complex_size  overlap_size  cluster_size
# 845      0.000002           196            17            98
# 841      0.000033            41             7            98
# 840      0.000074           614            29            98
# 517      0.000076            99            10            98
# 846      0.000078           141            12            98
# 674      0.000158           614            28            97
# 313      0.000249           136            11            98
# 1114     0.000273           210            14            98
# 338      0.000391           271            16            98
# 676      0.000396           100             9            97
# 777      0.000767           131            10            98
# 933      0.000932           210            13            98
# 543      0.001186           271            15            98
# 418      0.001186           271            15            98
# 930      0.001284           140            10            98
# 1120     0.001630           196            12            98
# 1113     0.002247            80             7            98
# 511      0.002286            41             5            98
# 957      0.002499           614            25            98
# 760      0.002499           614            25            98
# 673      0.002677           210            12            97
# 837      0.002776            83             7            98
# 507      0.002776            83             7            98
# 852      0.002920           210            12            98
# 839      0.002920           210            12            98
# 499      0.003338           271            14            98
# 1096     0.003671           271            14            99
# 549      0.003797           136             9            98
# 942      0.003797           136             9            98
# 678      0.004641           196            11            97
# 330      0.004826           141             9            98
# 150      0.004826           141             9            98
# 1091     0.004926           140             9            99
# 408      0.005021           196            11            98
# 515      0.005021           196            11            98
# 82       0.005021           196            11            98
# 498      0.005319           614            24            98
# 510      0.005319           614            24            98
# 122      0.005319           614            24            98
# 151      0.007379            99             7            98
# 513      0.007787           100             7            98
# 843      0.007787           100             7            98
# 308      0.007787           100             7            98
# 80       0.007787           100             7            98
# 509      0.008368           210            11            98
# 628      0.008368           210            11            98
# 247      0.008368           210            11            98
# 179      0.008368           210            11            98
# 1004     0.008368           210            11            98
# 685      0.008368           210            11            98
